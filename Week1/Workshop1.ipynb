# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from PIL import Image

# %%
image = Image.open("/content/drive/MyDrive/Ai_Ml/Data/lena_gray.gif")
display(image)
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=512x512>

# %%
print ( " Image Format : " , image . format )
print ( " Image Size : " , image . size )
print ( " Image Mode : " , image . mode )
# Out:
#  Image Format :  GIF
#  Image Size :  (512, 512)
#  Image Mode :  P

# %%
print ( " Image Format : " , image . format )
print ( " Image Size : " , image . size )
print ( " Image Mode : " , image . mode )
# Out:
#  Image Format :  GIF
#  Image Size :  (512, 512)
#  Image Mode :  P

# %%
width, height = image.size
channels = len(image.getbands())
print ( f" Image shape (RGB): ({ height } , { width } , { channels})")
image = width*height *3
print (f"Image size (RGB): {image}")
# Out:
#  Image shape (RGB): (512 , 512 , 1)
# Image size (RGB): 786432

# %%
import numpy as np
image_array_colored = np.array(image)
print("Shape of the image array:", image_array_colored.shape)
# Out:
# Shape of the image array: ()

# %%
image_array_colored = np.array(image)
print("Shape of the image array:", image_array_colored.shape)
# Out:
# Shape of the image array: (512, 512)

# %%
image_array_grayed = np . array ( image )
print("Shape of the image array:", image_array_grayed.shape)
# Out:
# Shape of the image array: (512, 512)

# %%
row_100 = image_array[ 100 , : ]
col_50 = image_array[ : , 50 ]
pixel = image_array[ 10 , 20 ]

# %%
left = 100
upper = 50
right = 200
lower = 150
cropped_image = image.crop((left, upper, right, lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=L size=100x100>

# %%
image_array = np . zeros ((100 , 100 , 3) , dtype = np . uint8 )
image_from_array = Image . fromarray ( image_array )
image_from_array . show ()

# %%
import numpy as np
import matplotlib . pyplot as plt
from PIL import Image
image = Image . open ("/content/drive/MyDrive/Ai_Ml/Data/cameraman.png") . convert ("L")
image_array = np . array ( image )
height , width = image_array . shape
data = image_array . reshape ( height , width )

# %%
mean = np.mean(data, axis= 0)
centered_data = data - mean
